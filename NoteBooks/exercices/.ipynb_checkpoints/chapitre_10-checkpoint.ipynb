# %%
# Chapitre 10:
# exercice 1:
import pandas as pd

df = pd.DataFrame({
    "name": ["Ahmed", "Mariem", "Hmada"],
    "age": [25, 30, 35]
})

print(df)
# Out:
#      name  age
# 0   Ahmed   25
# 1  Mariem   30
# 2   Hmada   35

# %%
# exercice 2:
print(df["age"])
# Out:
# 0    25
# 1    30
# 2    35
# Name: age, dtype: int64

# %%
# exercice 3:
filtered = df[df["age"] > 28]
print(filtered)
# Out:
#      name  age
# 1  Mariem   30
# 2   Hmada   35

# %%
# exercice 4:
df["age_plus_5"] = df["age"] + 5
print(df)
# Out:
#      name  age  age_plus_5
# 0   Ahmed   25          30
# 1  Mariem   30          35
# 2   Hmada   35          40

# %%
# exercice 5:
print(df["age"].mean())
# Out:
# 30.0

# %%
# exercice 6:
df2 = pd.DataFrame({
    "group": ["A", "A", "B"],
    "value": [10, 20, 30]
})

print(df2.groupby("group").mean())
# Out:
#        value
# group
# A       15.0
# B       30.0

# %%
# exercice 7:
print(df.sort_values(by="age"))
# Out:
#      name  age  age_plus_5
# 0   Ahmed   25          30
# 1  Mariem   30          35
# 2   Hmada   35          40

# %%
# exercice 8:
df3 = pd.DataFrame({
    "a": [1, None, 3]
})

print(df3.fillna(0))
# Out:
#      a
# 0  1.0
# 1  0.0
# 2  3.0

# %%
# exercice 9:
# df_csv = pd.read_csv("file.csv")
print("Simulation lecture CSV")
# Out:
# Simulation lecture CSV

# %%
# exercice 10:
import matplotlib.pyplot as plt

df["age"].plot()
plt.show()
