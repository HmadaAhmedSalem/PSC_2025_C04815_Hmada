# %%
# Chapitre 17:
# exercice 1:
import os
print(os.getcwd())
# Out:
# C:\Users\Hmada\Desktop\Doctorta\Python\chapitres_09_19_exercices_corriges

# %%
# exercice 2:
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'binary.bin', 'chapitre_09.ipynb', 'chapitre_10.ipynb', 'chapitre_11.ipynb', 'chapitre_12.ipynb', 'chapitre_13.ipynb', 'chapitre_14.ipynb', 'chapitre_15.ipynb', 'chapitre_16.ipynb', 'chapitre_17.ipynb', 'chapitre_18.ipynb', 'chapitre_19.ipynb', 'data.json', 'file.txt', 'list.txt', 'safe.txt', 'test.txt']

# %%
# exercice 3:
os.makedirs("test_dir", exist_ok=True)
print("Directory created")
# Out:
# Directory created

# %%
# exercice 4:
os.rmdir("test_dir")
print("Directory removed")
# Out:
# Directory removed

# %%
# exercice 5:
import subprocess
subprocess.run(["cmd", "/c", "echo Hello from system"])
# Out:
# CompletedProcess(args=['cmd', '/c', 'echo Hello from system'], returncode=0)

# %%
# exercice 6:
print(os.environ.get("PATH"))
# Out:
# C:\Users\Hmada\anaconda3;C:\Users\Hmada\anaconda3\Library\mingw-w64\bin;C:\Users\Hmada\anaconda3\Library\usr\bin;C:\Users\Hmada\anaconda3\Library\bin;C:\Users\Hmada\anaconda3\Scripts;C:\Program Files\Java\jdk-11.0.16\bin;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;D:\flutter\bin;C:\Program Files\dotnet\;C:\xampp8\php;C:\composer;C:\Users\Hmada\Downloads\symfony-cli_windows_amd64;C:\Program Files\Appache Maven\apache-maven-3.8.1\bin;C:\Users\Hmada\AppData\Local\Programs\Python\Python311;C:\Users\Hmada\.jpm\windows\bin;C:\Program Files\Utimaco\CryptoServer\Administration;C:\Program Files\Docker\Docker\resources\bin;C:\windows\system32;C:\Users\Hmada\AppData\Local\Programs\Python\Python311\Scripts;C:\Program Files\Git\cmd;C:\Program Files\PuTTY\;C:\Users\Hmada\AppData\Local\nvm;C:\nvm4w\nodejs;C:\WINDOWS\system32;C:\Program Files\Java\jdk-11.0.16\bin;C:\Users\Hmada\AppData\Local\Programs\Python\Python313\Scripts\;C:\Users\Hmada\AppData\Local\Programs\Python\Python313\;C:\Users\Hmada\AppData\Local\Microsoft\WindowsApps;C:\Users\Hmada\AppData\Local\Programs\Microsoft VS Code\bin;C:\Users\Hmada\AppData\Roaming\Composer\vendor\bin;C:\Users\Hmada\AppData\Roaming\npm;C:\Users\Hmada\AppData\Local\nvm;C:\nvm4w\nodejs;

# %%
# exercice 7:
path = os.path.join("folder", "file.txt")
print(path)
# Out:
# folder\file.txt

# %%
# exercice 8:
print(os.path.exists("file.txt"))
# Out:
# True

# %%
# exercice 9:
print(os.getpid())
# Out:
# 2284

# %%
# exercice 10:
result = subprocess.run("echo test", shell=True, capture_output=True, text=True)
print(result.stdout)
# Out:
# test
