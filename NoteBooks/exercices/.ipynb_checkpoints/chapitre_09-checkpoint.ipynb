# %%
# Chapitre 9:
# exercice 1:
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# exercice 2:
nums = [1, 2, 3, 4]
for n in nums:
    print(n * 2)
# Out:
# 2
# 4
# 6
# 8

# %%
# exercice 3:
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# exercice 4:
for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# exercice 5:
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
# exercice 6:
def my_generator(n):
    for i in range(n):
        yield i

for val in my_generator(5):
    print(val)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# exercice 7:
gen = (x**2 for x in range(5))
for v in gen:
    print(v)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
# exercice 8:
names = ["a", "b", "c"]
for i, name in enumerate(names):
    print(i, name)
# Out:
# 0 a
# 1 b
# 2 c

# %%
# exercice 9:
a = [1,2,3]
b = ['a','b','c']
for x,y in zip(a,b):
    print(x,y)
# Out:
# 1 a
# 2 b
# 3 c

# %%
# exercice 10:
i = 0
while True:
    print(i)
    if i == 3:
        break
    i += 1
# Out:
# 0
# 1
# 2
# 3
